# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.keras.utils import image_dataset_from_directory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import seaborn as sns
#       4 import pandas as pd
# ----> 5 from tensorflow.keras.utils import image_dataset_from_directory
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %% [markdown]
# Data Preparation

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
training_set = image_dataset_from_directory(
    "./train",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 76515 files belonging to 4 classes.

# %%
validation_set = image_dataset_from_directory(
    "./val",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 21861 files belonging to 4 classes.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\anaconda3\envs\tensorflow_env\Lib\site-packages\google\~-otobuf'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\AppData\Local\Temp\pip-uninstall-rk6tbhr8'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\anaconda3\envs\tensorflow_env\Lib\site-packages\tensorflow\lite\~xperimental'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.22.0 requires protobuf<4,>=3.12, but you have protobuf 4.25.9 which is incompatible.
# Collecting tensorflow<2.16,>=2.13
#   Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: tensorflow-intel==2.15.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow<2.16,>=2.13) (2.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.4.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (26.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (4.16.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (1.82.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.55.1)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Downloading google_auth_oauthlib-1.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.10.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.34.2)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.1.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (49.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2026.6.17)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.47.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (2.1.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<2.16,>=2.13) (3.0.3)
# Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl (2.1 kB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Downloading google_auth_oauthlib-1.4.1-py3-none-any.whl (19 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Installing collected packages: tensorflow-estimator, tensorboard-data-server, protobuf, keras, google-auth-oauthlib, tensorboard, tensorflow
#
#   Attempting uninstall: tensorflow-estimator
#
#     Found existing installation: tensorflow-estimator 2.10.0
#
#     Uninstalling tensorflow-estimator-2.10.0:
#
#       Successfully uninstalled tensorflow-estimator-2.10.0
#
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#   Attempting uninstall: tensorboard-data-server
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#     Found existing installation: tensorboard-data-server 0.6.1
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#     Uninstalling tensorboard-data-server-0.6.1:
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#       Successfully uninstalled tensorboard-data-server-0.6.1
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#   Attempting uninstall: protobuf
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#     Found existing installation: protobuf 3.19.6
#    ---------------------------------------- 0/7 [tensorflow-estimator]
#    ----------- ---------------------------- 2/7 [protobuf]
#     Uninstalling protobuf-3.19.6:
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#       Successfully uninstalled protobuf-3.19.6
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------- ---------------------------- 2/7 [protobuf]
#   Attempting uninstall: keras
#    ----------- ---------------------------- 2/7 [protobuf]
#     Found existing installation: keras 2.10.0
#    ----------- ---------------------------- 2/7 [protobuf]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#     Uninstalling keras-2.10.0:
#    ----------------- ---------------------- 3/7 [keras]
#       Successfully uninstalled keras-2.10.0
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#    ----------------- ---------------------- 3/7 [keras]
#   Attempting uninstall: google-auth-oauthlib
#    ----------------- ---------------------- 3/7 [keras]
#     Found existing installation: google-auth-oauthlib 0.4.6
#    ----------------- ---------------------- 3/7 [keras]
#     Uninstalling google-auth-oauthlib-0.4.6:
#    ----------------- ---------------------- 3/7 [keras]
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#    ----------------- ---------------------- 3/7 [keras]
#    ---------------------- ----------------- 4/7 [google-auth-oauthlib]
#   Attempting uninstall: tensorboard
#    ---------------------- ----------------- 4/7 [google-auth-oauthlib]
#     Found existing installation: tensorboard 2.10.1
#    ---------------------- ----------------- 4/7 [google-auth-oauthlib]
#    ---------------------------- ----------- 5/7 [tensorboard]
#     Uninstalling tensorboard-2.10.1:
#    ---------------------------- ----------- 5/7 [tensorboard]
#       Successfully uninstalled tensorboard-2.10.1
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------- ----------- 5/7 [tensorboard]
#   Attempting uninstall: tensorflow
#    ---------------------------- ----------- 5/7 [tensorboard]
#     Found existing installation: tensorflow 2.10.0
#    ---------------------------- ----------- 5/7 [tensorboard]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#     Uninstalling tensorflow-2.10.0:
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#       Successfully uninstalled tensorflow-2.10.0
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------- ----- 6/7 [tensorflow]
#    ---------------------------------------- 7/7 [tensorflow]
#
# Successfully installed google-auth-oauthlib-1.4.1 keras-2.15.0 protobuf-4.25.9 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0

# %%
training_set
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
INPUT_SHAPE = (224,224,3)

# %%
mobnet = tf.keras.applications.MobileNetV3Large(
    input_shape=INPUT_SHAPE,
    alpha=1.0,
    minimalistic=False,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    classes=1000,
    pooling=None,
    dropout_rate=0.2,
    classifier_activation="softmax",
    include_preprocessing=True,
    # name="MobileNetV3Large",
)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.Input(shape=INPUT_SHAPE))

# %%
mobnet = tf.keras.applications.MobileNetV3Large(
    input_shape=INPUT_SHAPE,
    include_top=False,      # drop the ImageNet classifier head
    weights="imagenet",
    pooling="avg",          # replaces the need for a separate GlobalAveragePooling2D
    dropout_rate=0.2,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 7s 1us/step

# %%
model.add(tf.keras.layers.Dense(units = 4,activation="softmax"))

# %%
metrics_list = ["accuracy"]

# %%
model_compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.0001),loss="categorical_crossentropy",metrics=metrics_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 model_compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.0001),loss="categorical_crossentropy",metrics=metrics_list)
#
# NameError: name 'model_compile' is not defined

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=metrics_list)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Functiona  (None, 1000)             5507432
#  l)
#
#  dense (Dense)               (None, 4)                 4004
#
#  dense_1 (Dense)             (None, 4)                 20
#
# =================================================================
# Total params: 5,511,456
# Trainable params: 5,487,056
# Non-trainable params: 24,400
# _________________________________________________________________

# %%
#training_history = model.fit(x=training_set,validation_data=validation_set,epochs=15)

# %%
# !pip check

# %%
# !pip uninstall tensorflow tensorflow-intel keras -y
# Out:
# Found existing installation: tensorflow 2.15.1
# Uninstalling tensorflow-2.15.1:
#   Successfully uninstalled tensorflow-2.15.1
# Found existing installation: tensorflow-intel 2.15.1
# Uninstalling tensorflow-intel-2.15.1:
#   Successfully uninstalled tensorflow-intel-2.15.1
# Found existing installation: keras 2.15.0
# Uninstalling keras-2.15.0:
#   Successfully uninstalled keras-2.15.0

# %%
# !pip install tensorflow==2.15.1
# Out:
# Collecting tensorflow==2.15.1
#   Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorflow-intel==2.15.1 (from tensorflow==2.15.1)
#   Using cached tensorflow_intel-2.15.1-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.4.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (4.25.9)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (4.16.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.82.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.1)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.55.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (1.4.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.10.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.34.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.1.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (49.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2026.6.17)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.47.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (2.1.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\user\anaconda3\envs\tensorflow_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.1) (3.0.3)
# Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.1-cp310-cp310-win_amd64.whl (300.9 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Installing collected packages: keras, tensorflow-intel, tensorflow
#
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ---------------------------------------- 0/3 [keras]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ------------- -------------------------- 1/3 [tensorflow-intel]
#    ---------------------------------------- 3/3 [tensorflow]
#
# Successfully installed keras-2.15.0 tensorflow-2.15.1 tensorflow-intel-2.15.1

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.keras.utils import image_dataset_from_directory
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
training_set = image_dataset_from_directory(
    "./train",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=8,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 76515 files belonging to 4 classes.

# %%
validation_set = image_dataset_from_directory(
    "./val",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=8,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 21861 files belonging to 4 classes.

# %%
training_set
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
INPUT_SHAPE = (224,224,3)

# %%
mobnet = tf.keras.applications.MobileNetV3Large(
    input_shape=INPUT_SHAPE,
    alpha=1.0,
    minimalistic=False,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    classes=1000,
    pooling=None,
    dropout_rate=0.2,
    classifier_activation="softmax",
    include_preprocessing=True,
    # name="MobileNetV3Large",
)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.Input(shape=INPUT_SHAPE))

# %%
model.add(mobnet)

# %%
model.add(tf.keras.layers.Dense(units = 4,activation="softmax"))

# %%
metrics_list = ["accuracy"]

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=metrics_list)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Functiona  (None, 1000)             5507432
#  l)
#
#  dense (Dense)               (None, 4)                 4004
#
# =================================================================
# Total params: 5,511,436
# Trainable params: 5,487,036
# Non-trainable params: 24,400
# _________________________________________________________________

# %%
training_history = model.fit(x=training_set,validation_data=validation_set,epochs=15)
# Out:
# Epoch 1/15
# 9565/9565 [==============================] - 736s 76ms/step - loss: 0.8520 - accuracy: 0.8399 - val_loss: 0.5402 - val_accuracy: 0.8938
# Epoch 2/15
# 9565/9565 [==============================] - 751s 79ms/step - loss: 0.4182 - accuracy: 0.9349 - val_loss: 0.3017 - val_accuracy: 0.9509
# Epoch 3/15
# 9565/9565 [==============================] - 749s 78ms/step - loss: 0.2497 - accuracy: 0.9533 - val_loss: 0.2076 - val_accuracy: 0.9528
# Epoch 4/15
# 9565/9565 [==============================] - 745s 78ms/step - loss: 0.1726 - accuracy: 0.9635 - val_loss: 0.1625 - val_accuracy: 0.9613
# Epoch 5/15
# 9565/9565 [==============================] - 744s 78ms/step - loss: 0.1291 - accuracy: 0.9714 - val_loss: 0.1204 - val_accuracy: 0.9701
# Epoch 6/15
# 9565/9565 [==============================] - 751s 78ms/step - loss: 0.1026 - accuracy: 0.9763 - val_loss: 0.1110 - val_accuracy: 0.9715
# Epoch 7/15
# 9565/9565 [==============================] - 750s 78ms/step - loss: 0.0880 - accuracy: 0.9801 - val_loss: 0.1265 - val_accuracy: 0.9635
# Epoch 8/15
# 9565/9565 [==============================] - 1252s 131ms/step - loss: 0.0746 - accuracy: 0.9824 - val_loss: 0.1192 - val_accuracy: 0.9695
# Epoch 9/15
# 9565/9565 [==============================] - 748s 78ms/step - loss: 0.0636 - accuracy: 0.9854 - val_loss: 0.8378 - val_accuracy: 0.7861
# Epoch 10/15
# 9565/9565 [==============================] - 751s 79ms/step - loss: 0.0583 - accuracy: 0.9864 - val_loss: 0.1135 - val_accuracy: 0.9691
# Epoch 11/15
# 9565/9565 [==============================] - 753s 79ms/step - loss: 0.0512 - accuracy: 0.9883 - val_loss: 0.0981 - val_accuracy: 0.9748
# Epoch 12/15
# 9565/9565 [==============================] - 747s 78ms/step - loss: 0.0465 - accuracy: 0.9894 - val_loss: 0.1178 - val_accuracy: 0.9723
# Epoch 13/15
# 9565/9565 [==============================] - 744s 78ms/step - loss: 0.0424 - accuracy: 0.9905 - val_loss: 0.1000 - val_accuracy: 0.9737
# Epoch 14/15
# 9565/9565 [==============================] - 852s 89ms/step - loss: 0.0403 - accuracy: 0.9903 - val_loss: 0.1097 - val_accuracy: 0.9716
# Epoch 15/15
# 9565/9565 [==============================] - 748s 78ms/step - loss: 0.0375 - accuracy: 0.9912 - val_loss: 0.1363 - val_accuracy: 0.9656

# %%
model.save("./Trained_Eye_disease_model.h5")

# %%
training_history.history
# Out:
# {'loss': [0.8519871234893799,
#   0.4181995689868927,
#   0.2496930956840515,
#   0.1726338416337967,
#   0.12913499772548676,
#   0.10256192833185196,
#   0.08797959238290787,
#   0.07458537071943283,
#   0.06359835714101791,
#   0.05830632522702217,
#   0.05118274688720703,
#   0.046548083424568176,
#   0.04237749055027962,
#   0.04032813012599945,
#   0.03751572221517563],
#  'accuracy': [0.8398614525794983,
#   0.9349278211593628,
#   0.9533032774925232,
#   0.9634842872619629,
#   0.9713912010192871,
#   0.976318359375,
#   0.9800823330879211,
#   0.9824478626251221,
#   0.9854276776313782,
#   0.9864470958709717,
#   0.9883291125297546,
#   0.989361584186554,
#   0.9905116558074951,
#   0.9903286695480347,
#   0.9911520481109619],
#  'val_loss': [0.5402039289474487,
#   0.30169036984443665,
#   0.2076459676027298,
#   0.1625186651945114,
#   0.12035544216632843,
#   0.11098586022853851,
#   0.1264984905719757,
#   0.11916285008192062,
#   0.8377667665481567,
#   0.11347417533397675,
#   0.09808643907308578,
#   0.11779768019914627,
#   0.10001879930496216,
#   0.10972114652395248,
#   0.1362898200750351],
#  'val_accuracy': [0.8938291668891907,
#   0.9509171843528748,
#   0.9527926445007324,
#   0.9613466858863831,
#   0.9700837135314941,
#   0.971455991268158,
#   0.9634509086608887,
#   0.9694890379905701,
#   0.7860573530197144,
#   0.9690773487091064,
#   0.9748410582542419,
#   0.97227942943573,
#   0.9736974239349365,
#   0.9715932607650757,
#   0.9655550718307495]}

# %%
import pickle
with open("Training_history.pkl","wb") as f:
    pickle.dump(training_history.history,f)
